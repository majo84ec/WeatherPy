# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates =list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city =citipy.nearest_city(coordinate[0], coordinate[1]).city_name 
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 714

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url ="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"'']
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]      
        city_description = city_weather["weather"][0]["description"]    
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description":city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jumla
# Processing Record 2 of Set 1 | tasiilaq
# Processing Record 3 of Set 1 | dhidhdhoo
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | kibala
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | kruisfontein
# Processing Record 8 of Set 1 | gisborne
# Processing Record 9 of Set 1 | akdepe
# Processing Record 10 of Set 1 | carson city
# Processing Record 11 of Set 1 | derzhavinsk
# Processing Record 12 of Set 1 | tommot
# Processing Record 13 of Set 1 | nome
# Processing Record 14 of Set 1 | slave lake
# Processing Record 15 of Set 1 | richards bay
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 1 | madridejos
# Processing Record 19 of Set 1 | viligili
# City not found. Skipping...
# Processing Record 20 of Set 1 | sao bento do sul
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | talhar
# Processing Record 23 of Set 1 | salvador
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | ardakan
# Processing Record 26 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 1 | barrow
# Processing Record 28 of Set 1 | rio gallegos
# Processing Record 29 of Set 1 | sao filipe
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | fortuna
# Processing Record 33 of Set 1 | turukhansk
# Processing Record 34 of Set 1 | nikolskoye
# Processing Record 35 of Set 1 | port alfred
# Processing Record 36 of Set 1 | pangnirtung
# Processing Record 37 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 1 | ponta delgada
# Processing Record 39 of Set 1 | camacha
# Processing Record 40 of Set 1 | puerto suarez
# Processing Record 41 of Set 1 | ushuaia
# Processing Record 42 of Set 1 | port lincoln
# Processing Record 43 of Set 1 | dasoguz
# Processing Record 44 of Set 1 | banjar
# Processing Record 45 of Set 1 | pisco
# Processing Record 46 of Set 1 | butaritari
# Processing Record 47 of Set 1 | kodiak
# Processing Record 48 of Set 1 | kapuskasing
# Processing Record 49 of Set 1 | la cumbre
# Processing Record 50 of Set 1 | vieux-habitants
# Processing Record 1 of Set 2 | cape town
# Processing Record 2 of Set 2 | victoria
# Processing Record 3 of Set 2 | chippewa falls
# Processing Record 4 of Set 2 | avila
# Processing Record 5 of Set 2 | lethem
# Processing Record 6 of Set 2 | mataura
# Processing Record 7 of Set 2 | alakurtti
# Processing Record 8 of Set 2 | qaanaaq
# Processing Record 9 of Set 2 | tuktoyaktuk
# Processing Record 10 of Set 2 | ambulu
# Processing Record 11 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 2 | thompson
# Processing Record 14 of Set 2 | atuona
# Processing Record 15 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 2 | bara
# Processing Record 17 of Set 2 | kosh-agach
# Processing Record 18 of Set 2 | albany
# Processing Record 19 of Set 2 | skibbereen
# Processing Record 20 of Set 2 | polovinnoye
# Processing Record 21 of Set 2 | kazachinskoye
# Processing Record 22 of Set 2 | puerto ayora
# Processing Record 23 of Set 2 | fare
# Processing Record 24 of Set 2 | ilulissat
# Processing Record 25 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 26 of Set 2 | salalah
# Processing Record 27 of Set 2 | maragogi
# Processing Record 28 of Set 2 | port elizabeth
# Processing Record 29 of Set 2 | caravelas
# Processing Record 30 of Set 2 | ndola
# Processing Record 31 of Set 2 | inirida
# Processing Record 32 of Set 2 | biak
# Processing Record 33 of Set 2 | aklavik
# Processing Record 34 of Set 2 | east london
# Processing Record 35 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 2 | kaitangata
# Processing Record 37 of Set 2 | souillac
# Processing Record 38 of Set 2 | hermanus
# Processing Record 39 of Set 2 | kautokeino
# Processing Record 40 of Set 2 | new norfolk
# Processing Record 41 of Set 2 | sistranda
# Processing Record 42 of Set 2 | coihaique
# Processing Record 43 of Set 2 | qaqortoq
# Processing Record 44 of Set 2 | saryozek
# Processing Record 45 of Set 2 | dondo
# Processing Record 46 of Set 2 | castro
# Processing Record 47 of Set 2 | upernavik
# Processing Record 48 of Set 2 | geraldton
# Processing Record 49 of Set 2 | christchurch
# Processing Record 50 of Set 2 | kapaa
# Processing Record 1 of Set 3 | yanchukan
# City not found. Skipping...
# Processing Record 2 of Set 3 | college
# Processing Record 3 of Set 3 | ponta do sol
# Processing Record 4 of Set 3 | udaipur
# Processing Record 5 of Set 3 | westport
# Processing Record 6 of Set 3 | fairbanks
# Processing Record 7 of Set 3 | lovozero
# Processing Record 8 of Set 3 | mar del plata
# Processing Record 9 of Set 3 | quatre cocos
# Processing Record 10 of Set 3 | yuzhno-kurilsk
# Processing Record 11 of Set 3 | preeceville
# Processing Record 12 of Set 3 | chervona sloboda
# Processing Record 13 of Set 3 | ribeira grande
# Processing Record 14 of Set 3 | carnarvon
# Processing Record 15 of Set 3 | katsuura
# Processing Record 16 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 17 of Set 3 | tadine
# Processing Record 18 of Set 3 | kirando
# Processing Record 19 of Set 3 | poum
# Processing Record 20 of Set 3 | tautira
# Processing Record 21 of Set 3 | saskylakh
# Processing Record 22 of Set 3 | hobart
# Processing Record 23 of Set 3 | russellville
# Processing Record 24 of Set 3 | ilinskaya
# Processing Record 25 of Set 3 | worland
# Processing Record 26 of Set 3 | helong
# Processing Record 27 of Set 3 | auki
# Processing Record 28 of Set 3 | yatou
# Processing Record 29 of Set 3 | kavieng
# Processing Record 30 of Set 3 | sarankhola
# Processing Record 31 of Set 3 | salinas
# Processing Record 32 of Set 3 | takoradi
# Processing Record 33 of Set 3 | killybegs
# Processing Record 34 of Set 3 | shingu
# Processing Record 35 of Set 3 | werda
# Processing Record 36 of Set 3 | bredasdorp
# Processing Record 37 of Set 3 | sosnovo-ozerskoye
# Processing Record 38 of Set 3 | vila franca do campo
# Processing Record 39 of Set 3 | talcahuano
# Processing Record 40 of Set 3 | laizhou
# Processing Record 41 of Set 3 | karakendzha
# City not found. Skipping...
# Processing Record 42 of Set 3 | kachug
# Processing Record 43 of Set 3 | hithadhoo
# Processing Record 44 of Set 3 | vostok
# Processing Record 45 of Set 3 | provideniya
# Processing Record 46 of Set 3 | pacific grove
# Processing Record 47 of Set 3 | itarema
# Processing Record 48 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 3 | tabas
# Processing Record 50 of Set 3 | arzgir
# Processing Record 1 of Set 4 | saint george
# Processing Record 2 of Set 4 | avarua
# Processing Record 3 of Set 4 | kokstad
# Processing Record 4 of Set 4 | aksarka
# Processing Record 5 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 4 | buon me thuot
# City not found. Skipping...
# Processing Record 7 of Set 4 | tuatapere
# Processing Record 8 of Set 4 | georgetown
# Processing Record 9 of Set 4 | taoudenni
# Processing Record 10 of Set 4 | pevek
# Processing Record 11 of Set 4 | tura
# Processing Record 12 of Set 4 | aporawan
# City not found. Skipping...
# Processing Record 13 of Set 4 | cabo san lucas
# Processing Record 14 of Set 4 | khatanga
# Processing Record 15 of Set 4 | bubaque
# Processing Record 16 of Set 4 | sao gabriel da cachoeira
# Processing Record 17 of Set 4 | mayo
# Processing Record 18 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 4 | hilo
# Processing Record 20 of Set 4 | comodoro rivadavia
# Processing Record 21 of Set 4 | pecos
# Processing Record 22 of Set 4 | asarganj
# Processing Record 23 of Set 4 | necochea
# Processing Record 24 of Set 4 | iqaluit
# Processing Record 25 of Set 4 | husavik
# Processing Record 26 of Set 4 | san cristobal
# Processing Record 27 of Set 4 | los llanos de aridane
# Processing Record 28 of Set 4 | moose factory
# Processing Record 29 of Set 4 | havoysund
# Processing Record 30 of Set 4 | barra patuca
# Processing Record 31 of Set 4 | jiayuguan
# Processing Record 32 of Set 4 | mount isa
# Processing Record 33 of Set 4 | saldanha
# Processing Record 34 of Set 4 | bambous virieux
# Processing Record 35 of Set 4 | acapulco
# Processing Record 36 of Set 4 | hermiston
# Processing Record 37 of Set 4 | anderson
# Processing Record 38 of Set 4 | cidreira
# Processing Record 39 of Set 4 | sao raimundo nonato
# Processing Record 40 of Set 4 | djibo
# Processing Record 41 of Set 4 | sebina
# Processing Record 42 of Set 4 | chaihe
# Processing Record 43 of Set 4 | astoria
# Processing Record 44 of Set 4 | yenagoa
# Processing Record 45 of Set 4 | anadyr
# Processing Record 46 of Set 4 | mukhen
# Processing Record 47 of Set 4 | marzuq
# Processing Record 48 of Set 4 | ayia galini
# Processing Record 49 of Set 4 | port augusta
# Processing Record 50 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 1 of Set 5 | mount gambier
# Processing Record 2 of Set 5 | yazd
# Processing Record 3 of Set 5 | jaru
# Processing Record 4 of Set 5 | bengkulu
# Processing Record 5 of Set 5 | nalut
# Processing Record 6 of Set 5 | lorengau
# Processing Record 7 of Set 5 | lebu
# Processing Record 8 of Set 5 | narsaq
# Processing Record 9 of Set 5 | lompoc
# Processing Record 10 of Set 5 | mao
# Processing Record 11 of Set 5 | makakilo city
# Processing Record 12 of Set 5 | anuradhapura
# Processing Record 13 of Set 5 | chuy
# Processing Record 14 of Set 5 | markova
# Processing Record 15 of Set 5 | umm kaddadah
# Processing Record 16 of Set 5 | bethel
# Processing Record 17 of Set 5 | iberia
# Processing Record 18 of Set 5 | beringovskiy
# Processing Record 19 of Set 5 | chokurdakh
# Processing Record 20 of Set 5 | mahabad
# Processing Record 21 of Set 5 | whyalla
# Processing Record 22 of Set 5 | sitka
# Processing Record 23 of Set 5 | ketchikan
# Processing Record 24 of Set 5 | kudahuvadhoo
# Processing Record 25 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 26 of Set 5 | ixtapa
# Processing Record 27 of Set 5 | esperance
# Processing Record 28 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 5 | san vicente
# Processing Record 30 of Set 5 | luderitz
# Processing Record 31 of Set 5 | beian
# Processing Record 32 of Set 5 | angoche
# Processing Record 33 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 5 | gazni
# City not found. Skipping...
# Processing Record 35 of Set 5 | chapais
# Processing Record 36 of Set 5 | sibu
# Processing Record 37 of Set 5 | maanshan
# Processing Record 38 of Set 5 | coquimbo
# Processing Record 39 of Set 5 | luau
# Processing Record 40 of Set 5 | touros
# Processing Record 41 of Set 5 | xining
# Processing Record 42 of Set 5 | buin
# Processing Record 43 of Set 5 | abay
# Processing Record 44 of Set 5 | kununurra
# Processing Record 45 of Set 5 | inzhavino
# Processing Record 46 of Set 5 | bangkalan
# Processing Record 47 of Set 5 | bereda
# Processing Record 48 of Set 5 | zaysan
# Processing Record 49 of Set 5 | shache
# Processing Record 50 of Set 5 | monte alegre
# Processing Record 1 of Set 6 | airai
# Processing Record 2 of Set 6 | mount pleasant
# Processing Record 3 of Set 6 | grindavik
# Processing Record 4 of Set 6 | vrangel
# Processing Record 5 of Set 6 | codrington
# Processing Record 6 of Set 6 | yar-sale
# Processing Record 7 of Set 6 | mahebourg
# Processing Record 8 of Set 6 | tiksi
# Processing Record 9 of Set 6 | arraial do cabo
# Processing Record 10 of Set 6 | saint-philippe
# Processing Record 11 of Set 6 | plettenberg bay
# Processing Record 12 of Set 6 | mabaruma
# Processing Record 13 of Set 6 | lagoa
# Processing Record 14 of Set 6 | bilibino
# Processing Record 15 of Set 6 | kulhudhuffushi
# Processing Record 16 of Set 6 | makokou
# Processing Record 17 of Set 6 | hamilton
# Processing Record 18 of Set 6 | pangai
# Processing Record 19 of Set 6 | longyearbyen
# Processing Record 20 of Set 6 | campbell river
# Processing Record 21 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 22 of Set 6 | mbandaka
# Processing Record 23 of Set 6 | gelnhausen
# Processing Record 24 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 6 | porbandar
# Processing Record 26 of Set 6 | hervey bay
# Processing Record 27 of Set 6 | bonavista
# Processing Record 28 of Set 6 | mahon
# Processing Record 29 of Set 6 | traralgon
# Processing Record 30 of Set 6 | bud
# Processing Record 31 of Set 6 | arlit
# Processing Record 32 of Set 6 | laguna
# Processing Record 33 of Set 6 | portland
# Processing Record 34 of Set 6 | nelson bay
# Processing Record 35 of Set 6 | santa isabel do rio negro
# Processing Record 36 of Set 6 | sterling
# Processing Record 37 of Set 6 | rolim de moura
# City not found. Skipping...
# Processing Record 38 of Set 6 | flinders
# Processing Record 39 of Set 6 | roseburg
# Processing Record 40 of Set 6 | olinda
# Processing Record 41 of Set 6 | moses lake
# Processing Record 42 of Set 6 | tezu
# Processing Record 43 of Set 6 | marsa matruh
# Processing Record 44 of Set 6 | cockburn town
# Processing Record 45 of Set 6 | praia da vitoria
# Processing Record 46 of Set 6 | eyl
# Processing Record 47 of Set 6 | leningradskiy
# Processing Record 48 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 49 of Set 6 | bathsheba
# Processing Record 50 of Set 6 | torbay
# Processing Record 1 of Set 7 | boddam
# Processing Record 2 of Set 7 | norman wells
# Processing Record 3 of Set 7 | boguchany
# Processing Record 4 of Set 7 | walcz
# Processing Record 5 of Set 7 | quelimane
# Processing Record 6 of Set 7 | nedjo
# Processing Record 7 of Set 7 | ambilobe
# Processing Record 8 of Set 7 | luganville
# Processing Record 9 of Set 7 | margate
# Processing Record 10 of Set 7 | ngunguru
# Processing Record 11 of Set 7 | lubana
# Processing Record 12 of Set 7 | port hedland
# Processing Record 13 of Set 7 | dikson
# Processing Record 14 of Set 7 | antanifotsy
# Processing Record 15 of Set 7 | keuruu
# Processing Record 16 of Set 7 | pangody
# Processing Record 17 of Set 7 | karpogory
# Processing Record 18 of Set 7 | khorixas
# Processing Record 19 of Set 7 | nipawin
# Processing Record 20 of Set 7 | hamina
# Processing Record 21 of Set 7 | klyuchi
# Processing Record 22 of Set 7 | koumac
# Processing Record 23 of Set 7 | miraflores
# Processing Record 24 of Set 7 | kropotkin
# Processing Record 25 of Set 7 | belaya gora
# Processing Record 26 of Set 7 | aquiraz
# Processing Record 27 of Set 7 | kampli
# Processing Record 28 of Set 7 | presidencia roque saenz pena
# Processing Record 29 of Set 7 | ostrovnoy
# Processing Record 30 of Set 7 | puri
# Processing Record 31 of Set 7 | pryazha
# Processing Record 32 of Set 7 | bekovo
# Processing Record 33 of Set 7 | avera
# Processing Record 34 of Set 7 | duncanville
# Processing Record 35 of Set 7 | cap malheureux
# Processing Record 36 of Set 7 | puro
# Processing Record 37 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 7 | kitimat
# Processing Record 39 of Set 7 | salamiyah
# Processing Record 40 of Set 7 | puerto escondido
# Processing Record 41 of Set 7 | karratha
# Processing Record 42 of Set 7 | puerto montt
# Processing Record 43 of Set 7 | filingue
# Processing Record 44 of Set 7 | klaksvik
# Processing Record 45 of Set 7 | port macquarie
# Processing Record 46 of Set 7 | dubenskiy
# City not found. Skipping...
# Processing Record 47 of Set 7 | lavrentiya
# Processing Record 48 of Set 7 | omsukchan
# Processing Record 49 of Set 7 | dafeng
# Processing Record 50 of Set 7 | avanigadda
# Processing Record 1 of Set 8 | buraydah
# Processing Record 2 of Set 8 | golovino
# Processing Record 3 of Set 8 | nemuro
# Processing Record 4 of Set 8 | namibe
# Processing Record 5 of Set 8 | tiarei
# Processing Record 6 of Set 8 | ruidoso
# Processing Record 7 of Set 8 | suileng
# Processing Record 8 of Set 8 | camalu
# Processing Record 9 of Set 8 | pyshchug
# Processing Record 10 of Set 8 | ijaki
# City not found. Skipping...
# Processing Record 11 of Set 8 | yumen
# Processing Record 12 of Set 8 | kupang
# Processing Record 13 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 8 | dagata
# City not found. Skipping...
# Processing Record 15 of Set 8 | singaparna
# Processing Record 16 of Set 8 | warangal
# Processing Record 17 of Set 8 | falealupo
# City not found. Skipping...
# Processing Record 18 of Set 8 | zhezkazgan
# Processing Record 19 of Set 8 | matara
# Processing Record 20 of Set 8 | kaifeng
# Processing Record 21 of Set 8 | babanusah
# City not found. Skipping...
# Processing Record 22 of Set 8 | mitsamiouli
# Processing Record 23 of Set 8 | storforshei
# Processing Record 24 of Set 8 | lafayette
# Processing Record 25 of Set 8 | santa rosa
# Processing Record 26 of Set 8 | kabompo
# Processing Record 27 of Set 8 | ambon
# Processing Record 28 of Set 8 | awjilah
# Processing Record 29 of Set 8 | chaman
# Processing Record 30 of Set 8 | siuna
# Processing Record 31 of Set 8 | faya
# Processing Record 32 of Set 8 | cayenne
# Processing Record 33 of Set 8 | pudozh
# Processing Record 34 of Set 8 | kuala selangor
# Processing Record 35 of Set 8 | la libertad
# Processing Record 36 of Set 8 | valparaiso
# Processing Record 37 of Set 8 | severo-kurilsk
# Processing Record 38 of Set 8 | drumheller
# Processing Record 39 of Set 8 | reefton
# City not found. Skipping...
# Processing Record 40 of Set 8 | ilo
# Processing Record 41 of Set 8 | orlik
# Processing Record 42 of Set 8 | elizabeth city
# Processing Record 43 of Set 8 | aykhal
# Processing Record 44 of Set 8 | zlobin
# Processing Record 45 of Set 8 | chimbote
# Processing Record 46 of Set 8 | berlevag
# Processing Record 47 of Set 8 | willmar
# Processing Record 48 of Set 8 | deputatskiy
# Processing Record 49 of Set 8 | ust-nera
# Processing Record 50 of Set 8 | mana
# Processing Record 1 of Set 9 | matane
# Processing Record 2 of Set 9 | almaznyy
# Processing Record 3 of Set 9 | igarka
# Processing Record 4 of Set 9 | ransang
# Processing Record 5 of Set 9 | luena
# Processing Record 6 of Set 9 | bababe
# City not found. Skipping...
# Processing Record 7 of Set 9 | kodinsk
# Processing Record 8 of Set 9 | urumqi
# Processing Record 9 of Set 9 | riyadh
# Processing Record 10 of Set 9 | marshall
# Processing Record 11 of Set 9 | karlstad
# Processing Record 12 of Set 9 | viedma
# Processing Record 13 of Set 9 | vao
# Processing Record 14 of Set 9 | harnosand
# Processing Record 15 of Set 9 | samarai
# Processing Record 16 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 9 | batticaloa
# Processing Record 18 of Set 9 | la ronge
# Processing Record 19 of Set 9 | meulaboh
# Processing Record 20 of Set 9 | kailua
# Processing Record 21 of Set 9 | san patricio
# Processing Record 22 of Set 9 | catalina
# Processing Record 23 of Set 9 | santa maria
# Processing Record 24 of Set 9 | conde
# Processing Record 25 of Set 9 | sattahip
# Processing Record 26 of Set 9 | rawlins
# Processing Record 27 of Set 9 | scarborough
# Processing Record 28 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 9 | labe
# Processing Record 30 of Set 9 | petropavlovka
# Processing Record 31 of Set 9 | port blair
# Processing Record 32 of Set 9 | aasiaat
# Processing Record 33 of Set 9 | xuddur
# Processing Record 34 of Set 9 | sept-iles
# Processing Record 35 of Set 9 | kaohsiung
# Processing Record 36 of Set 9 | biltine
# Processing Record 37 of Set 9 | medicine hat
# Processing Record 38 of Set 9 | constitucion
# Processing Record 39 of Set 9 | polunochnoye
# Processing Record 40 of Set 9 | norsup
# Processing Record 41 of Set 9 | goderich
# Processing Record 42 of Set 9 | vila velha
# Processing Record 43 of Set 9 | orichi
# Processing Record 44 of Set 9 | cururupu
# Processing Record 45 of Set 9 | nola
# Processing Record 46 of Set 9 | vadso
# Processing Record 47 of Set 9 | szentlorinc
# Processing Record 48 of Set 9 | vicosa do ceara
# Processing Record 49 of Set 9 | staryy nadym
# Processing Record 50 of Set 9 | grand gaube
# Processing Record 1 of Set 10 | kainantu
# Processing Record 2 of Set 10 | gondanglegi
# Processing Record 3 of Set 10 | inhambane
# Processing Record 4 of Set 10 | nanortalik
# Processing Record 5 of Set 10 | buta
# Processing Record 6 of Set 10 | sahuaripa
# Processing Record 7 of Set 10 | zambezi
# Processing Record 8 of Set 10 | vanavara
# Processing Record 9 of Set 10 | caala
# Processing Record 10 of Set 10 | andenes
# Processing Record 11 of Set 10 | zabol
# Processing Record 12 of Set 10 | duldurga
# Processing Record 13 of Set 10 | potsdam
# Processing Record 14 of Set 10 | vwawa
# Processing Record 15 of Set 10 | kholmogory
# Processing Record 16 of Set 10 | alice springs
# Processing Record 17 of Set 10 | awbari
# Processing Record 18 of Set 10 | ust-omchug
# Processing Record 19 of Set 10 | winnemucca
# Processing Record 20 of Set 10 | ojinaga
# Processing Record 21 of Set 10 | yerbogachen
# Processing Record 22 of Set 10 | bairiki
# Processing Record 23 of Set 10 | tunxi
# City not found. Skipping...
# Processing Record 24 of Set 10 | harper
# Processing Record 25 of Set 10 | asyut
# Processing Record 26 of Set 10 | labuhan
# Processing Record 27 of Set 10 | namatanai
# Processing Record 28 of Set 10 | apostolove
# Processing Record 29 of Set 10 | carballo
# Processing Record 30 of Set 10 | eureka
# Processing Record 31 of Set 10 | eenhana
# Processing Record 32 of Set 10 | clyde river
# Processing Record 33 of Set 10 | san carlos de bariloche
# Processing Record 34 of Set 10 | zhuhai
# Processing Record 35 of Set 10 | tashtyp
# Processing Record 36 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 10 | pangkalanbuun
# Processing Record 38 of Set 10 | ancud
# Processing Record 39 of Set 10 | tiruvottiyur
# City not found. Skipping...
# Processing Record 40 of Set 10 | de-kastri
# Processing Record 41 of Set 10 | buala
# Processing Record 42 of Set 10 | boa vista
# Processing Record 43 of Set 10 | labrea
# Processing Record 44 of Set 10 | saint-leu
# Processing Record 45 of Set 10 | zetel
# Processing Record 46 of Set 10 | satipo
# Processing Record 47 of Set 10 | lewistown
# Processing Record 48 of Set 10 | maromitsa
# Processing Record 49 of Set 10 | shenjiamen
# Processing Record 50 of Set 10 | illela
# Processing Record 1 of Set 11 | pagudpud
# Processing Record 2 of Set 11 | bilma
# Processing Record 3 of Set 11 | seoul
# Processing Record 4 of Set 11 | vestmannaeyjar
# Processing Record 5 of Set 11 | kawalu
# Processing Record 6 of Set 11 | paranga
# Processing Record 7 of Set 11 | saint anthony
# Processing Record 8 of Set 11 | tual
# Processing Record 9 of Set 11 | concepcion del oro
# Processing Record 10 of Set 11 | korem
# Processing Record 11 of Set 11 | general salgado
# Processing Record 12 of Set 11 | jieshi
# Processing Record 13 of Set 11 | saint-pierre
# Processing Record 14 of Set 11 | ruteng
# Processing Record 15 of Set 11 | padang
# Processing Record 16 of Set 11 | bandarbeyla
# Processing Record 17 of Set 11 | abaza
# Processing Record 18 of Set 11 | sao joao da barra
# Processing Record 19 of Set 11 | te anau
# Processing Record 20 of Set 11 | raudeberg
# Processing Record 21 of Set 11 | aitape
# Processing Record 22 of Set 11 | washington
# Processing Record 23 of Set 11 | kutum
# Processing Record 24 of Set 11 | katangli
# Processing Record 25 of Set 11 | ranau
# Processing Record 26 of Set 11 | cherskiy
# Processing Record 27 of Set 11 | kavaratti
# Processing Record 28 of Set 11 | kendari
# Processing Record 29 of Set 11 | tomatlan
# Processing Record 30 of Set 11 | port hardy
# Processing Record 31 of Set 11 | tiznit
# Processing Record 32 of Set 11 | venezuela
# Processing Record 33 of Set 11 | jalu
# Processing Record 34 of Set 11 | osmena
# Processing Record 35 of Set 11 | tanhacu
# Processing Record 36 of Set 11 | trapani
# Processing Record 37 of Set 11 | rawson
# Processing Record 38 of Set 11 | port moresby
# Processing Record 39 of Set 11 | komsomolskiy
# Processing Record 40 of Set 11 | saint-augustin
# Processing Record 41 of Set 11 | yeppoon
# Processing Record 42 of Set 11 | khudumelapye
# Processing Record 43 of Set 11 | yirol
# City not found. Skipping...
# Processing Record 44 of Set 11 | haines junction
# Processing Record 45 of Set 11 | araouane
# Processing Record 46 of Set 11 | torrelavega
# Processing Record 47 of Set 11 | umm lajj
# Processing Record 48 of Set 11 | san joaquin
# Processing Record 49 of Set 11 | gobabis
# Processing Record 50 of Set 11 | zhanaozen
# Processing Record 1 of Set 12 | okha
# Processing Record 2 of Set 12 | tungkang
# City not found. Skipping...
# Processing Record 3 of Set 12 | dourbali
# Processing Record 4 of Set 12 | tabou
# Processing Record 5 of Set 12 | sao jose da coroa grande
# Processing Record 6 of Set 12 | rudsar
# Processing Record 7 of Set 12 | wagar
# Processing Record 8 of Set 12 | zakamensk
# Processing Record 9 of Set 12 | beidao
# Processing Record 10 of Set 12 | nhulunbuy
# Processing Record 11 of Set 12 | columbus
# Processing Record 12 of Set 12 | cherlak
# Processing Record 13 of Set 12 | san pedro
# Processing Record 14 of Set 12 | qui nhon
# Processing Record 15 of Set 12 | homer
# Processing Record 16 of Set 12 | sorland
# Processing Record 17 of Set 12 | broken hill
# Processing Record 18 of Set 12 | burica
# City not found. Skipping...
# Processing Record 19 of Set 12 | tyulgan
# Processing Record 20 of Set 12 | santa vitoria do palmar
# Processing Record 21 of Set 12 | rio claro
# Processing Record 22 of Set 12 | manicore
# Processing Record 23 of Set 12 | oksfjord
# Processing Record 24 of Set 12 | brandon
# Processing Record 25 of Set 12 | hirara
# Processing Record 26 of Set 12 | yunhe
# Processing Record 27 of Set 12 | iracoubo
# Processing Record 28 of Set 12 | toftir
# City not found. Skipping...
# Processing Record 29 of Set 12 | slonim
# Processing Record 30 of Set 12 | balintore
# Processing Record 31 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 32 of Set 12 | zhangye
# Processing Record 33 of Set 12 | srandakan
# Processing Record 34 of Set 12 | tougue
# Processing Record 35 of Set 12 | clyde
# Processing Record 36 of Set 12 | lumberton
# Processing Record 37 of Set 12 | moron
# Processing Record 38 of Set 12 | ahipara
# Processing Record 39 of Set 12 | redmond
# Processing Record 40 of Set 12 | faanui
# Processing Record 41 of Set 12 | atar
# Processing Record 42 of Set 12 | krasnoborsk
# Processing Record 43 of Set 12 | tucuma
# Processing Record 44 of Set 12 | sturgeon falls
# Processing Record 45 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 12 | basoko
# Processing Record 47 of Set 12 | key west
# Processing Record 48 of Set 12 | abeche
# Processing Record 49 of Set 12 | dali
# Processing Record 50 of Set 12 | magdagachi
# Processing Record 1 of Set 13 | watsa
# Processing Record 2 of Set 13 | porto novo
# Processing Record 3 of Set 13 | prince rupert
# Processing Record 4 of Set 13 | lucapa
# Processing Record 5 of Set 13 | erenhot
# Processing Record 6 of Set 13 | harlingen
# Processing Record 7 of Set 13 | tawau
# Processing Record 8 of Set 13 | chiang khong
# Processing Record 9 of Set 13 | yushan
# Processing Record 10 of Set 13 | guerrero negro
# Processing Record 11 of Set 13 | the valley
# Processing Record 12 of Set 13 | sagae
# Processing Record 13 of Set 13 | acarau
# Processing Record 14 of Set 13 | isangel
# Processing Record 15 of Set 13 | ukiah
# Processing Record 16 of Set 13 | beyneu
# Processing Record 17 of Set 13 | roald
# Processing Record 18 of Set 13 | ola
# Processing Record 19 of Set 13 | shelburne
# Processing Record 20 of Set 13 | udankudi
# Processing Record 21 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 22 of Set 13 | merauke
# Processing Record 23 of Set 13 | simao
# Processing Record 24 of Set 13 | arkadelphia
# Processing Record 25 of Set 13 | nyazepetrovsk
# Processing Record 26 of Set 13 | gao
# Processing Record 27 of Set 13 | pacifica
# Processing Record 28 of Set 13 | nha trang
# Processing Record 29 of Set 13 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 30 of Set 13 | barranca
# Processing Record 31 of Set 13 | coahuayana
# Processing Record 32 of Set 13 | ayr
# Processing Record 33 of Set 13 | arandis
# Processing Record 34 of Set 13 | barra do corda
# Processing Record 35 of Set 13 | nioro
# Processing Record 36 of Set 13 | praxedis guerrero
# Processing Record 37 of Set 13 | port-gentil
# Processing Record 38 of Set 13 | santa lucia
# Processing Record 39 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 40 of Set 13 | yining
# Processing Record 41 of Set 13 | kayes
# Processing Record 42 of Set 13 | acajutla
# Processing Record 43 of Set 13 | khandyga
# Processing Record 44 of Set 13 | plainview
# Processing Record 45 of Set 13 | colwyn bay
# Processing Record 46 of Set 13 | bengkalis
# City not found. Skipping...
# Processing Record 47 of Set 13 | mountain home
# Processing Record 48 of Set 13 | kewanee
# Processing Record 49 of Set 13 | skiros
# City not found. Skipping...
# Processing Record 50 of Set 13 | darhan
# Processing Record 1 of Set 14 | ocos
# Processing Record 2 of Set 14 | guadalupe y calvo
# Processing Record 3 of Set 14 | seredeyskiy
# Processing Record 4 of Set 14 | jaciara
# Processing Record 5 of Set 14 | asau
# Processing Record 6 of Set 14 | japura
# Processing Record 7 of Set 14 | giddalur
# Processing Record 8 of Set 14 | ndele
# Processing Record 9 of Set 14 | pelym
# Processing Record 10 of Set 14 | khilok
# Processing Record 11 of Set 14 | cabedelo
# Processing Record 12 of Set 14 | cuamba
# Processing Record 13 of Set 14 | new iberia
# Processing Record 14 of Set 14 | bardiyah
# Processing Record 15 of Set 14 | kieta
# Processing Record 16 of Set 14 | agadez
# Processing Record 17 of Set 14 | warora
# Processing Record 18 of Set 14 | hualmay
# Processing Record 19 of Set 14 | micheweni
# Processing Record 20 of Set 14 | ongandjera
# Processing Record 21 of Set 14 | egvekinot
# Processing Record 22 of Set 14 | panjab
# Processing Record 23 of Set 14 | mahibadhoo
# Processing Record 24 of Set 14 | otradnoye
# Processing Record 25 of Set 14 | maksatikha
# Processing Record 26 of Set 14 | bichura
# Processing Record 27 of Set 14 | puerto carreno
# Processing Record 28 of Set 14 | glenwood springs
# Processing Record 29 of Set 14 | atherton
# Processing Record 30 of Set 14 | guamuchil
# Processing Record 31 of Set 14 | sosnytsya
# Processing Record 32 of Set 14 | posse
# Processing Record 33 of Set 14 | sinnamary
# Processing Record 34 of Set 14 | mergui
# City not found. Skipping...
# Processing Record 35 of Set 14 | peniche
# Processing Record 36 of Set 14 | farafangana
# Processing Record 37 of Set 14 | oussouye
# Processing Record 38 of Set 14 | kerema
# Processing Record 39 of Set 14 | alofi
# Processing Record 40 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 41 of Set 14 | felidhoo
# City not found. Skipping...
# Processing Record 42 of Set 14 | solnechnyy
# Processing Record 43 of Set 14 | nikel
# Processing Record 44 of Set 14 | fort nelson
# Processing Record 45 of Set 14 | alyangula
# Processing Record 46 of Set 14 | ondorhaan
# City not found. Skipping...
# Processing Record 47 of Set 14 | machali
# Processing Record 48 of Set 14 | oltu
# Processing Record 49 of Set 14 | baykit
# Processing Record 50 of Set 14 | savelugu
# Processing Record 1 of Set 15 | maniitsoq
# Processing Record 2 of Set 15 | nayagarh
# Processing Record 3 of Set 15 | srednekolymsk
# Processing Record 4 of Set 15 | goundam
# Processing Record 5 of Set 15 | havelock
# Processing Record 6 of Set 15 | daugai
# Processing Record 7 of Set 15 | diamantino
# Processing Record 8 of Set 15 | lazurne
# Processing Record 9 of Set 15 | waddan
# Processing Record 10 of Set 15 | ostroh
# Processing Record 11 of Set 15 | dvubratskiy
# Processing Record 12 of Set 15 | sibiti
# Processing Record 13 of Set 15 | hit
# Processing Record 14 of Set 15 | troitskoye
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 660

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Jumla  29.2747   82.1838     34.20        58           0
# 1      Tasiilaq  65.6145  -37.6368     17.76        75          35
# 2     Dhidhdhoo   6.8833   73.1000     80.53        73           8
# 3       Rikitea -23.1203 -134.9692     78.46        74          72
# 4        Kibala   9.1104   18.3463     98.78         9           8
# 5         Vaini -21.2000 -175.2000     75.36        94          20
# 6  Kruisfontein -34.0033   24.7314     66.88        56          97
# 7      Gisborne -38.6533  178.0042     62.55        94         100
# 8        Akdepe  42.0551   59.3788     30.92        42           6
# 9   Carson City  39.1638 -119.7674     33.33        73         100
#
#    Wind Speed Country                 Date Current Description
# 0        7.99      NP  2023-01-29 16:15:45           clear sky
# 1        5.61      GL  2023-01-29 16:12:31    scattered clouds
# 2       10.92      MV  2023-01-29 16:09:30           clear sky
# 3       10.71      PF  2023-01-29 16:12:31       broken clouds
# 4        4.85      TD  2023-01-29 16:15:45           clear sky
# 5        0.00      TO  2023-01-29 16:12:34          few clouds
# 6       15.14      ZA  2023-01-29 16:15:46     overcast clouds
# 7        6.04      NZ  2023-01-29 16:15:46     overcast clouds
# 8        9.89      TM  2023-01-29 16:15:47           clear sky
# 9       10.36      US  2023-01-29 16:13:57     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed", "Current Description"
new_column_order =['City', 'Country','Date', 'Lat', 'Lng', 'Max Temp', 'Humidity',  'Cloudiness', 'Wind Speed','Current Description']

# Recreate the DataFrame by using the new column order
city_data_df=city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0         Jumla      NP  2023-01-29 16:15:45  29.2747   82.1838     34.20
# 1      Tasiilaq      GL  2023-01-29 16:12:31  65.6145  -37.6368     17.76
# 2     Dhidhdhoo      MV  2023-01-29 16:09:30   6.8833   73.1000     80.53
# 3       Rikitea      PF  2023-01-29 16:12:31 -23.1203 -134.9692     78.46
# 4        Kibala      TD  2023-01-29 16:15:45   9.1104   18.3463     98.78
# 5         Vaini      TO  2023-01-29 16:12:34 -21.2000 -175.2000     75.36
# 6  Kruisfontein      ZA  2023-01-29 16:15:46 -34.0033   24.7314     66.88
# 7      Gisborne      NZ  2023-01-29 16:15:46 -38.6533  178.0042     62.55
# 8        Akdepe      TM  2023-01-29 16:15:47  42.0551   59.3788     30.92
# 9   Carson City      US  2023-01-29 16:13:57  39.1638 -119.7674     33.33
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        58           0        7.99           clear sky
# 1        75          35        5.61    scattered clouds
# 2        73           8       10.92           clear sky
# 3        74          72       10.71       broken clouds
# 4         9           8        4.85           clear sky
# 5        94          20        0.00          few clouds
# 6        56          97       15.14     overcast clouds
# 7        94         100        6.04     overcast clouds
# 8        42           6        9.89           clear sky
# 9        73         100       10.36     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Date                    object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "C:/Users/Jorge/Desktop/BCanvas/Modulo_API/Weather_Database/WeatherPy_Database.csv"
# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file,index_label="City_ID")
